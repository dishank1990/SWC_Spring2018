# %%
import pandas as pd
from plotnine import *
# Out:
# C:\Users\Dishank\Anaconda3\lib\site-packages\statsmodels\compat\pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %%
my_file = pd.read_table('gapminder.txt')

# %%
my_file
# Out:
#           country continent  year  lifeExp       pop    gdpPercap
# 0     Afghanistan      Asia  1952   28.801   8425333   779.445314
# 1     Afghanistan      Asia  1957   30.332   9240934   820.853030
# 2     Afghanistan      Asia  1962   31.997  10267083   853.100710
# 3     Afghanistan      Asia  1967   34.020  11537966   836.197138
# 4     Afghanistan      Asia  1972   36.088  13079460   739.981106
# 5     Afghanistan      Asia  1977   38.438  14880372   786.113360
# 6     Afghanistan      Asia  1982   39.854  12881816   978.011439
# 7     Afghanistan      Asia  1987   40.822  13867957   852.395945
# 8     Afghanistan      Asia  1992   41.674  16317921   649.341395
# 9     Afghanistan      Asia  1997   41.763  22227415   635.341351
# 10    Afghanistan      Asia  2002   42.129  25268405   726.734055
# 11    Afghanistan      Asia  2007   43.828  31889923   974.580338
# 12        Albania    Europe  1952   55.230   1282697  1601.056136
# ...

# %%
who
# Out:
# aes	 annotate	 arrow	 as_labeller	 coord_cartesian	 coord_equal	 coord_fixed	 coord_flip	 coord_trans
# element_blank	 element_line	 element_rect	 element_text	 expand_limits	 facet_grid	 facet_null	 facet_wrap	 geom_abline
# geom_area	 geom_bar	 geom_bin2d	 geom_blank	 geom_boxplot	 geom_col	 geom_count	 geom_crossbar	 geom_density
# geom_dotplot	 geom_errorbar	 geom_errorbarh	 geom_freqpoly	 geom_histogram	 geom_hline	 geom_jitter	 geom_label	 geom_line
# geom_linerange	 geom_path	 geom_point	 geom_pointrange	 geom_polygon	 geom_qq	 geom_quantile	 geom_rect	 geom_ribbon
# geom_rug	 geom_segment	 geom_smooth	 geom_spoke	 geom_step	 geom_text	 geom_tile	 geom_violin	 geom_vline
# ggplot	 ggsave	 ggtitle	 guide_colorbar	 guide_colourbar	 guide_legend	 guides	 label_both	 label_context
# label_value	 labeller	 labs	 lims	 my_file	 pd	 position_dodge	 position_fill	 position_identity
# ...

# %%
pd
# Out:
# <module 'pandas' from 'C:\\Users\\Dishank\\Anaconda3\\lib\\site-packages\\pandas\\__init__.py'>

# %%
(ggplot(my_file) + aes(x = 'gdpPercap', y = 'lifeExp') + geom_point())
# Out:
# <ggplot: (-9223371940389865493)>

# %%
aes --help
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-aa5d7a44ffad> in <module>()
# ----> 1 aes --help
#
# TypeError: bad operand type for unary -: '_Helper'

# %%
help aes
# Out:
#   File "<ipython-input-8-63832c3e1dfe>", line 1
#     help aes
#            ^
# SyntaxError: invalid syntax

# %%
help(aes)
# Out:
# Help on class aes in module plotnine.aes:
#
# class aes(builtins.dict)
#  |  Create aesthetic mappings
#  |
#  |  Parameters
#  |  ----------
#  |  x : str | array_like | scalar | str-expression
#  |      x aesthetic mapping
#  |  y : str | array_like | scalar | str-expression
#  |      y aesthetic mapping
#  |
#  |  **kwargs : dict
#  |      Other aesthetic mappings
#  |
#  |
#  |  The value of each mapping must be one of;
#  |
#  |  - **string**::
#  |
#  |          import pandas as pd
#  |          import numpy as np
#  |
#  |          arr = [11, 12, 13]
#  |          df = pd.DataFrame({'alpha': [1, 2, 3],
#  |                             'beta': [1, 2, 3],
#  |                             'gam ma': [1, 2, 3]})
#  |
#  |          # Refer to a column in a dataframe
#  |          ggplot(df, aes(x='alpha', y='beta'))
#  |
#  |  - **array_like**::
#  |
#  |          # A variable
#  |          ggplot(df, aes(x='alpha', y=[4, 5, 6]))
#  |
#  |          # or an inplace list
# ...

# %%
(ggplot(my_file) + aes(x = 'year', y = 'pop') + geom_point())
# Out:
# <ggplot: (-9223371940388135932)>

# %%
(ggplot(my_file) + aes(x = 'pop', y = 'lifeExp') + geom_point())
# Out:
# <ggplot: (-9223371940388111612)>

# %%
(ggplot(my_file) + aes(x = 'pop', y = 'lifeExp',color = 'continent') + geom_point())
# Out:
# <ggplot: (96466686756)>

# %%
(ggplot(my_file) + aes(x = 'pop', y = 'lifeExp',color = 'continent', by = 'country') + geom_line())
# Out:
# <ggplot: (-9223371940386642779)>

# %%
(ggplot(my_file) + aes(x = 'year', y = 'lifeExp',color = 'continent', by = 'country') + geom_line())
# Out:
# <ggplot: (-9223371940386622783)>

# %%
(ggplot(my_file) + aes(x = 'year', y = 'lifeExp',color = 'continent', by = 'country') + geom_point() + geom_line())
# Out:
# <ggplot: (-9223371940386408967)>

# %%
(ggplot(my_file) + aes(x = 'year', y = 'lifeExp',color = 'continent', by = 'country') + geom_line() + geom_point() )
# Out:
# <ggplot: (96466758478)>

# %%
country = my_file[my_file.country.str.startswith('A') ]
(ggplot(country) + aes(x = 'year', y = 'lifeExp',color = 'continent', by = 'country') + geom_line() + facet_wrap('country') )
# Out:
# <ggplot: (96468068125)>

# %%
my_file.country.str.startswith('A')
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
# 5        True
# 6        True
# 7        True
# 8        True
# 9        True
# 10       True
# 11       True
# 12       True
# 13       True
# 14       True
# 15       True
# 16       True
# 17       True
# 18       True
# 19       True
# 20       True
# 21       True
# 22       True
# 23       True
# 24       True
# 25       True
# 26       True
# 27       True
# 28       True
# 29       True
#         ...
# 1674    False
# 1675    False
# 1676    False
# 1677    False
# 1678    False
# 1679    False
# 1680    False
# 1681    False
# 1682    False
# 1683    False
# 1684    False
# 1685    False
# 1686    False
# 1687    False
# 1688    False
# 1689    False
# 1690    False
# 1691    False
# 1692    False
# 1693    False
# 1694    False
# 1695    False
# 1696    False
# 1697    False
# 1698    False
# 1699    False
# 1700    False
# 1701    False
# 1702    False
# 1703    False
# ...
